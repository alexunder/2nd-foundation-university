# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_rel
from scipy.stats import ttest_ind

dataframe = pd.read_csv("PPS.csv")
display(dataframe)

before_mean = np.mean(dataframe.before)
before_std = np.std(dataframe.before)
print("Before mean=" + str(before_mean))
print("Before std=" + str(before_std))

print("The Before Sum of squared deviations=" + str(dataframe.before.size*(before_std**2)))
    
after_mean = np.mean(dataframe.after)
after_std = np.std(dataframe.after)
print("After mean=" + str(after_mean))
print("After std=" + str(after_std))

print("The After Sum of squared deviations=" + str(dataframe.after.size*(after_std**2)))

ttest_ind(dataframe.before, dataframe.after, equal_var=False)
# Out:
#     before  after
# 0      4.2    8.0
# 1      7.7    6.2
# 2      3.3    4.1
# 3      4.7    7.3
# 4      4.9    5.4
# 5      5.1    6.1
# 6      6.8    7.5
# 7      4.7    7.8
# 8      3.3    9.5
# 9      7.0    4.5
# 10     5.1    8.2
# 11     5.9    5.9
# 12     7.5    6.4
# 13     3.9    8.4
# Before mean=5.292857142857143
# Before std=1.4199920954077203
# The Before Sum of squared deviations=28.229285714285716
# After mean=6.807142857142859
# After std=1.4964072620371605
# The After Sum of squared deviations=31.349285714285717
# Ttest_indResult(statistic=-2.6466619667043418, pvalue=0.013636590198673021)

# %%
import pandas as pd
import numpy as np
from scipy.stats import ttest_rel
from scipy.stats import ttest_ind

dataframe = pd.read_csv("HW-a.csv")
display(dataframe)

a_mean = np.mean(dataframe['Project A'])
a_std  = np.std(dataframe['Project A'])

b_mean = np.mean(dataframe['Project B'])
b_std  = np.std(dataframe['Project B'])

print("Project A's mean=" + str(a_mean))
print("Project B's mean=" + str(b_mean))
print("Project A's std=" + str(a_std))
print("Project B's std=" + str(b_std))

t, prob = ttest_ind(dataframe['Project A'], dataframe['Project B'], equal_var=False)

print("t test value=" + str(t))
print("Prob P value =" + str(prob))
# Out:
#    Project A  Project B
# 0         17         28
# 1         24         30
# 2         23         32
# 3         18         13
# 4         15         32
# 5         21         28
# 6         17         20
# 7         21         19
# 8         17         32
# 9         24         15
# Project A's mean=19.7
# Project B's mean=24.9
# Project A's std=3.1320919526731648
# Project B's std=7.034912934784623
# t test value=-2.02580319465
# Prob P value =0.0647982236048
